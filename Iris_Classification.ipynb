# %% [markdown]
# <a href="https://colab.research.google.com/github/Sagnik220/Iris-Classification-GRADIO/blob/main/Iris_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gradio as gr
from pycaret.datasets import get_data
from pycaret.classification import *
# Out:
# /home/ishita/miniconda3/envs/ml38/lib/python3.8/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (2.0.3)/charset_normalizer (2.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
# load the iris dataset from pycaret repo
data = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# initialize setup
s = setup(data, target = 'species', session_id = 123)
# Out:
# <style  type="text/css" >
# #T_4a3f7_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_4a3f7_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a3f7_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4a3f7_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_4a3f7_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4a3f7_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_4a3f7_row1_col1" class="data row1 col1" >species</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4a3f7_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_4a3f7_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4a3f7_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_4a3f7_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4a3f7_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_4a3f7_row4_col1" class="data row4 col1" >(150, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4a3f7_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_4a3f7_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4a3f7_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_4a3f7_row6_col1" class="data row6 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4a3f7_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_4a3f7_row7_col1" class="data row7 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4a3f7_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_4a3f7_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_4a3f7_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_4a3f7_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_4a3f7_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_4a3f7_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_4a3f7_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_4a3f7_row11_col1" class="data row11 col1" >(104, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_4a3f7_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_4a3f7_row12_col1" class="data row12 col1" >(46, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_4a3f7_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_4a3f7_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_4a3f7_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_4a3f7_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_4a3f7_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_4a3f7_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_4a3f7_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_4a3f7_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_4a3f7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_4a3f7_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_4a3f7_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_4a3f7_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_4a3f7_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_4a3f7_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_4a3f7_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_4a3f7_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_4a3f7_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_4a3f7_row21_col1" class="data row21 col1" >95af</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_4a3f7_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_4a3f7_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_4a3f7_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_4a3f7_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_4a3f7_level0_row

# %%
best = compare_models(n_select = 15)
compare_model_results = pull()
# Out:
# <style  type="text/css" >
#     #T_66c5e_ th {
#           text-align: left;
#     }#T_66c5e_row0_col0,#T_66c5e_row1_col0,#T_66c5e_row1_col1,#T_66c5e_row1_col2,#T_66c5e_row1_col3,#T_66c5e_row1_col4,#T_66c5e_row1_col5,#T_66c5e_row1_col6,#T_66c5e_row1_col7,#T_66c5e_row2_col0,#T_66c5e_row2_col1,#T_66c5e_row2_col3,#T_66c5e_row2_col4,#T_66c5e_row2_col5,#T_66c5e_row2_col6,#T_66c5e_row2_col7,#T_66c5e_row3_col0,#T_66c5e_row3_col1,#T_66c5e_row3_col2,#T_66c5e_row3_col3,#T_66c5e_row3_col4,#T_66c5e_row3_col5,#T_66c5e_row3_col6,#T_66c5e_row3_col7,#T_66c5e_row4_col0,#T_66c5e_row4_col1,#T_66c5e_row4_col2,#T_66c5e_row4_col3,#T_66c5e_row4_col4,#T_66c5e_row4_col5,#T_66c5e_row4_col6,#T_66c5e_row4_col7,#T_66c5e_row5_col0,#T_66c5e_row5_col1,#T_66c5e_row5_col2,#T_66c5e_row5_col3,#T_66c5e_row5_col4,#T_66c5e_row5_col5,#T_66c5e_row5_col6,#T_66c5e_row5_col7,#T_66c5e_row6_col0,#T_66c5e_row6_col1,#T_66c5e_row6_col2,#T_66c5e_row6_col3,#T_66c5e_row6_col4,#T_66c5e_row6_col5,#T_66c5e_row6_col6,#T_66c5e_row6_col7,#T_66c5e_row7_col0,#T_66c5e_row7_col1,#T_66c5e_row7_col2,#T_66c5e_row7_col3,#T_66c5e_row7_col4,#T_66c5e_row7_col5,#T_66c5e_row7_col6,#T_66c5e_row7_col7,#T_66c5e_row8_col0,#T_66c5e_row8_col1,#T_66c5e_row8_col2,#T_66c5e_row8_col3,#T_66c5e_row8_col4,#T_66c5e_row8_col5,#T_66c5e_row8_col6,#T_66c5e_row8_col7,#T_66c5e_row9_col0,#T_66c5e_row9_col1,#T_66c5e_row9_col2,#T_66c5e_row9_col3,#T_66c5e_row9_col4,#T_66c5e_row9_col5,#T_66c5e_row9_col6,#T_66c5e_row9_col7,#T_66c5e_row10_col0,#T_66c5e_row10_col1,#T_66c5e_row10_col2,#T_66c5e_row10_col3,#T_66c5e_row10_col4,#T_66c5e_row10_col5,#T_66c5e_row10_col6,#T_66c5e_row10_col7,#T_66c5e_row11_col0,#T_66c5e_row11_col1,#T_66c5e_row11_col2,#T_66c5e_row11_col3,#T_66c5e_row11_col4,#T_66c5e_row11_col5,#T_66c5e_row11_col6,#T_66c5e_row11_col7,#T_66c5e_row12_col0,#T_66c5e_row12_col1,#T_66c5e_row12_col2,#T_66c5e_row12_col3,#T_66c5e_row12_col4,#T_66c5e_row12_col5,#T_66c5e_row12_col6,#T_66c5e_row12_col7,#T_66c5e_row13_col0,#T_66c5e_row13_col1,#T_66c5e_row13_col2,#T_66c5e_row13_col3,#T_66c5e_row13_col4,#T_66c5e_row13_col5,#T_66c5e_row13_col6,#T_66c5e_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_66c5e_row0_col1,#T_66c5e_row0_col2,#T_66c5e_row0_col3,#T_66c5e_row0_col4,#T_66c5e_row0_col5,#T_66c5e_row0_col6,#T_66c5e_row0_col7,#T_66c5e_row2_col2{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_66c5e_row0_col8,#T_66c5e_row1_col8,#T_66c5e_row2_col8,#T_66c5e_row3_col8,#T_66c5e_row5_col8,#T_66c5e_row6_col8,#T_66c5e_row7_col8,#T_66c5e_row8_col8,#T_66c5e_row9_col8,#T_66c5e_row10_col8,#T_66c5e_row11_col8,#T_66c5e_row12_col8,#T_66c5e_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_66c5e_row4_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_66c5e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66c5e_level0_row0" class="row_heading level0 row0" >lda</th>
#                         <td id="T_66c5e_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#                         <td id="T_66c5e_row0_col1" class="data row0 col1" >0.9809</td>
#                         <td id="T_66c5e_row0_col2" class="data row0 col2" >0.9969</td>
#                         <td id="T_66c5e_row0_col3" class="data row0 col3" >0.9833</td>
#                         <td id="T_66c5e_row0_col4" class="data row0 col4" >0.9857</td>
#                         <td id="T_66c5e_row0_col5" class="data row0 col5" >0.9809</td>
#                         <td id="T_66c5e_row0_col6" class="data row0 col6" >0.9715</td>
#                         <td id="T_66c5e_row0_col7" class="data row0 col7" >0.9739</td>
#                         <td id="T_66c5e_row0_col8" class="data row0 col8" >0.0230</td>
#             </tr>
#             <tr>
#                         <th id="T_66c5e_level0_row1" class="row_heading level0 row1" >knn</th>
#                         <td id="T_66c5e_row1_col0" class="data row1 col0" >K Neighbors Classifier</td>
#                         <td id="T_66c5e_row1_col1" class="data row1 col1" >0.9800</td>
#                         <td id="T_66c5e_row1_col2" class="data row1 col2" >0.9830</td>
#                         <td id="T_66c5e_row1_col3" class="data row1 col3" >0.9806</td>
#                         <td id="T_66c5e_row1_col4" class="data row1 col4" >0.9800</td>
#                         <td id="T_66c5e_row1_col5" class="data row1 col5" >0.9800</td>
#                         <td id="T_66c5e_row1_col6" class="data row1 col6" >0.9697</td>
#                         <td id="T_66c5e_row1_col7" class="data row1 col7" >0.9697</td>
#                         <td id="T_66c5e_row1_col8" class="data row1 col8" >0.1120</td>
#             </tr>
#             <tr>
#                         <th id="T_66c5e_level0_row2" class="row_heading level0 row2" >qda</th>
#                         <td id="T_66c5e_row2_col0" class="data row2 col0" >Quadratic Discriminant Analysis</td>
#                         <td id="T_66c5e_row2_col1" class="data row2 col1" >0.9709</td>
#                         <td id="T_66c5e_row2_col2" class="data row2 col2" >0.9969</td>
#                         <td id="T_66c5e_row2_col3" class="data row2 col3" >0.9750</td>
#                         <td id="T_66c5e_row2_col4" class="data row2 col4" >0.9782</td>
#                         <td id="T_66c5e_row2_col5" class="data row2 col5" >0.9709</td>
#                         <td id="T_66c5e_row2_col6" class="data row2 col6" >0.9566</td>
#                         <td id="T_66c5e_row2_col7" class="data row2 col7" >0.9602</td>
#                         <td id="T_66c5e_row2_col8" class="data row2 col8" >0.0200</td>
#             </tr>
#             <tr>
#                         <th id="T_66c5e_level0_row3" class="row_heading level0 row3" >lr</th>
#                         <td id="T_66c5e_row3_col0" class="data row3 col0" >Logistic Regression</td>
#                         <td id="T_66c5e_row3_col1" class="data row3 col1" >0.9609</td>
#                         <td id="T_66c5e_row3_col2" class="data row3 col2" >0.9921</td>
#                         <td id="T_66c5e_row3_col3" class="data row3 col3" >0.9611</td>
#                         <td id="T_66c5e_row3_col4" class="data row3 col4" >0.9622</td>
#                         <td id="T_66c5e_row3_col5" class="data row3 col5" >0.9596</td>
#                         <td id="T_66c5e_row3_col6" class="data row3 col6" >0.9403</td>
#                         <td id="T_66c5e_row3_col7" class="data row3 col7" >0.9422</td>
#                         <td id="T_66c5e_row3_col8" class="data row3 col8" >1.7890</td>
#             </tr>
#             <tr>
#                         <th id="T_66c5e_level0_row4" class="row_heading level0 row4" >nb</th>
#                         <td id="T_66c5e_row4_col0" class="data row4 col0" >Naive Bayes</td>
#                         <td id="T_66c5e_row4_col1" class="data row4 col1" >0.9609</td>
#                         <td id="T_66c5e_row4_col2" class="data row4 col2" >0.9938</td>
#                         <td id="T_66c5e_row4_col3" class="data row4 col3" >0.9611</td>
#                         <td id="T_66c5e_row4_col4" class="data row4 col4" >0.9652</td>
#                         <td id="T_66c5e_row4_col5" class="data row4 col5" >0.9605</td>
#                         <td id="T_66c5e_row4_col6" class="data row4 c

# %%
# creating a predict function to be passed into gradio UI
def predict(model, sepal_length, sepal_width, petal_length, petal_width):
  
    df = pd.DataFrame.from_dict({'sepal_length': [sepal_length], 'sepal_width': [sepal_width], 
                                 'petal_length': [petal_length], 'petal_width': [petal_width]})
    
    model_index = list(compare_model_results['Model']).index(model)
    model = best[model_index]
    pred = predict_model(model, df, raw_score=True)
    return {'Iris-setosa': pred['Score_Iris-setosa'][0].astype('float64'), 
            'Iris-versicolor': pred['Score_Iris-versicolor'][0].astype('float64'),
            'Iris-virginica' : pred['Score_Iris-virginica'][0].astype('float64')}

# %%
model = gr.inputs.Dropdown(list(compare_model_results['Model']), label="Model")
sepal_length = gr.inputs.Slider(minimum=1, maximum=10, default=data['sepal_length'].mean(), label = 'sepal_length')
sepal_width = gr.inputs.Slider(minimum=1, maximum=10, default=data['sepal_width'].mean(), label = 'sepal_width')
petal_length = gr.inputs.Slider(minimum=1, maximum=10, default=data['petal_length'].mean(), label = 'petal_length')
petal_width = gr.inputs.Slider(minimum=1, maximum=10, default=data['petal_width'].mean(), label = 'petal_width')

gr.Interface(predict, [model,sepal_length,sepal_width,petal_length,petal_width], "label", live=True).launch()
# Out:
# Running locally at: http://127.0.0.1:7861/
# To create a public link, set `share=True` in `launch()`.
# Interface loading below...
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7861/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# (<Flask 'gradio.networking'>, 'http://127.0.0.1:7861/', None)
